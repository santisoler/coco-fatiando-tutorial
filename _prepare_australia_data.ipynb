# %%
import numpy as np
import pandas as pd
import xarray as xr
import pyproj
import pygmt

import pooch
import boule as bl
import verde as vd
import harmonica as hm

# %% [markdown]
# ## Download data

# %%
# Download and cache the CSV version (no metadata)
fname = pooch.retrieve(
    url="doi:10.6084/m9.figshare.13643837/australia-ground-gravity.csv",
    known_hash="md5:d47fef200d92c682dc8b63fe31b80364",
    progressbar=True,
)

# Load the data with pandas
data = pd.read_csv(fname)
data
# Out:
#            gravity  gravity_accuracy  height_error  reliability_index  \
# 0        979314.81               0.2         10.06                  1
# 1        979322.00               0.2         10.06                  1
# 2        979303.88               0.2         10.06                  1
# 3        979306.88               0.2         10.06                  1
# 4        979320.62               0.2         10.06                  1
# ...            ...               ...           ...                ...
# 1789360  978682.50               0.2          6.16                  4
# 1789361  978698.88               0.2          6.16                  4
# 1789362  978721.31               0.2          6.16                  4
# 1789363  978956.88               0.2          6.16                  4
# 1789364  978629.12               0.2          6.16                  4
#
#          survey_id   longitude   latitude  height
# 0           195951  138.620497 -31.117129  515.11
# 1           195951  138.612697 -31.128329  470.83
# 2           195951  138.755195 -31.094027  541.83
# 3           195951  138.764895 -31.088427  526.33
# 4           195951  138.825194 -31.086327  462.98
# ...            ...         ...        ...     ...
# 1789360     196111  133.229599 -24.218554  602.45
# 1789361     196111  135.242914 -23.478536  457.36
# 1789362     196111  132.416280 -24.560232  565.01
# 1789363     196111  139.114555 -25.496838  103.87
# 1789364     196111  137.439533 -21.080187  256.03
#
# [1789365 rows x 8 columns]

# %%
region = (128, 136, -26, -20)

coordinates = (data.longitude, data.latitude)
inside = vd.inside(coordinates, region)

data = data[inside]
data
# Out:
#            gravity  gravity_accuracy  height_error  reliability_index  \
# 11000    978632.00              0.01          5.06                  1
# 11008    978834.62              0.60          1.06                  1
# 11009    978831.62              0.60          1.06                  1
# 11010    978828.19              0.60          1.06                  1
# 11011    978827.00              0.60          1.06                  1
# ...            ...               ...           ...                ...
# 1789351  978848.12              0.20          6.16                  4
# 1789358  978630.62              0.20          6.16                  4
# 1789360  978682.50              0.20          6.16                  4
# 1789361  978698.88              0.20          6.16                  4
# 1789362  978721.31              0.20          6.16                  4
#
#          survey_id   longitude   latitude  height
# 11000       196600  135.237899 -21.750203  424.24
# 11008       199681  129.690032 -25.649330  687.99
# 11009       199681  129.705192 -25.638730  690.41
# 11010       199681  129.727941 -25.624080  695.85
# 11011       199681  129.747611 -25.619539  700.10
# ...            ...         ...        ...     ...
# 1789351     196111  134.827933 -25.023543  352.75
# 1789358     196111  131.917941 -23.280232  640.69
# 1789360     196111  133.229599 -24.218554  602.45
# 1789361     196111  135.242914 -23.478536  457.36
# 1789362     196111  132.416280 -24.560232  565.01
#
# [101047 rows x 8 columns]

# %%
reducer = vd.BlockReduce(
    np.median, spacing=4 / 60, region=region, drop_coords=False
)

# %%
coords, gravity = reducer.filter((data.longitude, data.latitude, data.height), data.gravity)

# %%
coords[0].size
# Out:
# 10061

# %%
df = pd.DataFrame(
    {"longitude": coords[0], "latitude": coords[1], "height": coords[2], "gravity": gravity}
)

# %%
df
# Out:
#         longitude   latitude   height     gravity
# 0      128.032600 -25.970810  504.725  978886.250
# 1      128.101040 -25.973100  512.860  978878.310
# 2      128.153118 -25.981983  522.385  978873.000
# 3      128.225848 -25.977600  529.460  978873.380
# 4      128.300600 -25.974300  548.660  978873.690
# ...           ...        ...      ...         ...
# 10056  135.708050 -20.020412  284.040  978562.750
# 10057  135.765300 -20.020502  282.070  978561.845
# 10058  135.804100 -20.037377  277.640  978557.880
# 10059  135.898550 -20.019515  273.005  978556.310
# 10060  135.974650 -20.019206  272.875  978557.380
#
# [10061 rows x 4 columns]

# %%
fig = pygmt.Figure()
pygmt.makecpt(
    cmap="viridis",
    series=[df.gravity.min(), df.gravity.max()]
)
fig.plot(
    x=df.longitude,
    y=df.latitude,
    color=df.gravity,
    cmap=True, 
    style="c2p",  # circles with 4px as diameter
    projection="M15c",  # mercator projection with 15cm of width
    frame="afg"
)
fig.coast(shorelines="black", area_thresh=1e6)
fig.colorbar(frame='af+l"observed gravity [mGal]')
fig.show()

# %%
df.to_csv("homework_data/australia_gravity.csv", index=False)
